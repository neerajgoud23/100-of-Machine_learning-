# %% [markdown]
# <a href="https://colab.research.google.com/github/neerajgoud23/100-of-Machine_learning-/blob/main/Day5_Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/customer.csv')
df.head()
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 3    72  Female     Good        PG        No
# 31   22  Female     Poor    School       Yes
# 44   77  Female  Average        UG        No
# 23   96  Female     Good    School        No
# 22   18  Female     Poor        PG       Yes

# %%
df = df.iloc[:,2:]
df
# Out:
#      review education purchased
# 0   Average    School        No
# 1      Poor        UG        No
# 2      Good        PG        No
# 3      Good        PG        No
# 4   Average        UG        No
# 5   Average    School       Yes
# 6      Good    School        No
# 7      Poor    School       Yes
# 8   Average        UG        No
# 9      Good        UG       Yes
# 10     Good        UG       Yes
# 11     Good        UG       Yes
# 12     Poor    School        No
# 13  Average    School        No
# 14     Poor        PG       Yes
# 15     Poor        UG        No
# 16     Poor        UG       Yes
# 17     Poor        UG       Yes
# 18     Good    School        No
# 19     Poor        PG       Yes
# 20  Average    School       Yes
# 21  Average        PG        No
# 22     Poor        PG       Yes
# 23     Good    School        No
# 24  Average        PG       Yes
# 25     Good    School        No
# 26     Poor        PG        No
# 27     Poor        PG        No
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2,random_state=0)

# %%
x_train
# Out:
#      review education
# 33     Good        PG
# 35     Poor    School
# 26     Poor        PG
# 34  Average    School
# 18     Good    School
# 7      Poor    School
# 14     Poor        PG
# 45     Poor        PG
# 48     Good        UG
# 29  Average        UG
# 15     Poor        UG
# 30  Average        UG
# 32  Average        UG
# 16     Poor        UG
# 42     Good        PG
# 20  Average    School
# 43     Poor        PG
# 8   Average        UG
# 13  Average    School
# 25     Good    School
# 5   Average    School
# 17     Poor        UG
# 40     Good    School
# 49     Good        UG
# 1      Poor        UG
# 12     Poor    School
# 37  Average        PG
# 24  Average        PG
# 6      Good    School
# 23     Good    School
# 36     Good        UG
# 21  Average        PG
# 19     Poor        PG
# 9      Good        UG
# 39     Poor        PG
# 46     Poor        PG
# 3      Good        PG
# 0   Average    School
# 47     Good        PG
# 44  Average        UG

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(x_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
x_train = oe.transform(x_train)
x_test = oe.transform(x_test)

# %%
x_test
# Out:
# array([[0., 0.],
#        [2., 1.],
#        [2., 1.],
#        [2., 2.],
#        [2., 2.],
#        [0., 2.],
#        [2., 0.],
#        [0., 0.],
#        [0., 2.],
#        [1., 1.]])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
le.fit(y_test)
# Out:
# LabelEncoder()

# %%
y_train=le.transform(y_train)
y_test = le.transform(y_test)

# %%
y_test
# Out:
# array([0, 1, 1, 1, 0, 0, 0, 1, 1, 0])

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, 1, 1, 1, 0, 0, 1, 0])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.5
